# %% [markdown]
# y(x, t) = A * sin{2*Pi(t/T - x/lambda)}

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
Pi = np.pi

# %%
lambda_ = 2 # longueur d'onde en m
x = np.linspace(0, 5*lambda_, 256)

# %%
A = 1.5 # amplitude en ua
phi = 0 # déphasage (en multiple de Pi/4)

# %%
y = A*np.cos(2*Pi*x/lambda_ + phi)

# %%
plt.figure()
plt.plot(x, y, 'o-')
plt.ylabel('Amplitude (ua)')
plt.xlabel('Distance (m)')
plt.title('t = 0')
plt.show()

# %%
# %matplotlib inline
lambda_ = 2
x = np.linspace(0, 5*lambda_, 256)
phi = 0
for t in range(9):
    y = A*np.cos(2*Pi*x/lambda_ - phi)
    plt.figure()
    plt.plot(x, y)
    plt.scatter(t*lambda_/4, A, color='red')
    plt.scatter(t*lambda_/4+3*lambda_, A*math.cos(6*Pi), color='green')
    delta = 1.3
    plt.scatter(t*lambda_/4+delta*lambda_, A*math.cos(2*delta*Pi), color='black')
    plt.ylabel('Amplitude (ua)')
    plt.xlabel('Distance (m)')
    plt.title('t = '+str(t)+'T/4')
    plt.show()
    phi += Pi/2 # à chaque 1/4 de période, le déphasage d'amplitude de chaque point du milieu est de Pi/2

# %%
# %matplotlib notebook
legende = ['0', 'T/4', 'T/2', '3T/4', 'T', '5T/4', '3T/2', '7T/4', '2T']
A = 1.5
lambda_ = 2
x = np.linspace(0, 5*lambda_, 256)
phi = 0
plt.figure()
for t in range(9):
    y = A*np.cos(2*Pi*x/lambda_ - phi)
    plt.subplot(3, 3, t+1)
    plt.plot(x, y)
    plt.scatter(t*lambda_/4, A, color='red')
    plt.scatter(t*lambda_/4+3*lambda_, A*math.cos(6*Pi), color='green')
    delta = 1.3
    plt.scatter(t*lambda_/4+delta*lambda_, A*math.cos(2*delta*Pi), color='black')
    plt.ylabel('Amplitude (ua)')
    plt.xlabel('Distance (m)')
    plt.title('t = '+legende[t])
    phi += Pi/2 # à chaque 1/4 de période, le déphasage d'amplitude de chaque point du milieu est de Pi/2

plt.tight_layout() # ajoute de l'espace entre les Axes pour visualiser tout le texte (ticks et title)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="431.75000000000006">

# %%
# %matplotlib notebook
A = 1.5
lambda_ = 2
x = np.linspace(0, 5*lambda_, 256)
phi = 0
plt.figure()
for t in range(9):
    y = A*np.cos(2*Pi*x/lambda_ - phi)
    plt.subplot(10, 1, t+1)
    plt.plot(x, y)
    plt.scatter(t*lambda_/4, A, color='red')
    plt.scatter(t*lambda_/4+3*lambda_, A*math.cos(6*Pi), color='green')
    delta = 1.3
    plt.scatter(t*lambda_/4+delta*lambda_, A*math.cos(2*delta*Pi), color='black')
    phi += Pi/2 # à chaque 1/4 de période, le déphasage d'amplitude de chaque point du milieu est de Pi/2
    
plt.xlabel('Distance (m)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="431.75000000000006">

# %%
# %matplotlib notebook
T = 2 # période en s
t = np.linspace(0, 5*T, 256)
phi = 0

plt.figure()
y = A*np.cos(2*Pi*t/T - phi)
plt.plot(t, y)
plt.ylabel('Amplitude (ua)')
plt.xlabel('Temps (s)')
plt.title('Amplitude en un point du milieu au cours du temps')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="431.75000000000006">

# %% [markdown]
# # Tests

# %%
# %matplotlib inline
fig, axes = plt.subplots(9, 1, sharex='col')
phi = 0
for t in range(9):
    y = A*np.cos(2*Pi*x/lambda_ - phi)
    axes[t].plot(x, y)
    axes[t].scatter(t*lambda_/4, A, color='red')
    axes[t].scatter(t*lambda_/4+3*lambda_, A*math.cos(6*Pi), color='green')
    delta = 1.3
    axes[t].scatter(t*lambda_/4+delta*lambda_, A*math.cos(2*delta*Pi), color='black')
    phi += Pi/2 # à chaque 1/4 de période, le déphasage d'amplitude de chaque point du milieu est de Pi/2

axes[8].set(xlabel='Distance (m)')  
axes[5].set(ylabel='Amplitude (ua)')  
axes[0,].set(title="Propagation d'une onde") 
plt.show()
plt.show()

# %%
fig, axes = plt.subplots(3, 3, sharex='col', sharey='row')
phi= 0
for t in range(9):
    y = A*np.cos(2*Pi*x/lambda_ - phi)
    axes[t//3, t%3].plot(x, y)
    axes[t//3, t%3].scatter(t*lambda_/4, A, color='red')
    axes[t//3, t%3].scatter(t*lambda_/4+3*lambda_, A*math.cos(6*Pi), color='green')
    delta = 1.3
    axes[t//3, t%3].scatter(t*lambda_/4+delta*lambda_, A*math.cos(2*delta*Pi), color='black')
    phi += Pi/2 # à chaque 1/4 de période, le déphasage d'amplitude de chaque point du milieu est de Pi/2
    axes[t//3, 0].set(ylabel='Ampl')

axes[2, 1].set(xlabel='Distance (m)')  
axes[0, 1].set(title="Propagation d'une onde") 
plt.show()

# %%
#plt.style.use('classic')

fig, axes = plt.subplots(3, 6, sharex='col', sharey='row', figsize=(12, 5))
phi= 0
for t in range(18):
    y = A*np.cos(2*Pi*x/lambda_ - phi)
    axes[t//6, t%6].plot(x, y)
    axes[t//6, t%6].scatter(t*lambda_/4, A, color='red')
    phi += Pi/2 # à chaque 1/4 de période, le déphasage d'amplitude de chaque point du milieu est de Pi/2
    axes[t//6,  0].set(ylabel='Ampl')

axes[2, 2].set(xlabel='Distance (m)')  
fig.suptitle("Propagation d'une onde") 
plt.show()
